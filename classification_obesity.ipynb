# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("ObesityDataSet.csv")
d
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
d.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
d.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
d.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2106    False
# 2107    False
# 2108    False
# 2109    False
# 2110    False
# Length: 2111, dtype: bool

# %%
r=d["NObeyesdad"].unique()
plt.pie(d["NObeyesdad"].value_counts(),labels=r)
# Out:
# ([<matplotlib.patches.Wedge at 0x19857baa240>,
# ...
#  [Text(0.9533093018443864, 0.5488181620691581, 'Normal_Weight'),
#   Text(0.04827659413120045, 1.098940112316905, 'Overweight_Level_I'),
#   Text(-0.8480026696961722, 0.7006364764898876, 'Overweight_Level_II'),
#   Text(-1.081622638065542, -0.2002310386132419, 'Obesity_Type_I'),
#   Text(-0.5509448613808724, -0.9520818030600162, 'Insufficient_Weight'),
#   Text(0.3607122048336628, -1.039175974166088, 'Obesity_Type_II'),
#   Text(1.0111033311950712, -0.43320901842670617, 'Obesity_Type_III')])

# %%
sns.histplot(x=d["Age"],kde=True,data=d,bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x=d["Weight"],kde=True,data=d,bins=20)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
sns.countplot(x=d["NObeyesdad"],hue=d["Gender"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.scatterplot(x=d["Height"],y=d["Weight"],hue=d["Gender"])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.barplot(x=d["NObeyesdad"],y=d["Weight"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["Height"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["FCVC"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["CH2O"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["FAF"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["TUE"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["NObeyesdad"],y=d["NCP"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.scatterplot(x=d["Age"],y=d["Weight"],hue=d["Gender"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.countplot(x=d["NObeyesdad"],data=d,hue=d["SMOKE"])
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
sns.barplot(x=d["SMOKE"],y=d["Weight"],hue=d["Gender"],data=d)
# Out:
# <Axes: xlabel='SMOKE', ylabel='Weight'>

# %%
sns.barplot(x=d["SMOKE"],y=d["Age"],hue=d["Gender"],data=d)
# Out:
# <Axes: xlabel='SMOKE', ylabel='Age'>

# %%
sns.barplot(x=d["NObeyesdad"],y=d["Age"],hue=d["Gender"],data=d)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Normal_Weight'),
#   Text(1, 0, 'Overweight_Level_I'),
#   Text(2, 0, 'Overweight_Level_II'),
#   Text(3, 0, 'Obesity_Type_I'),
#   Text(4, 0, 'Insufficient_Weight'),
#   Text(5, 0, 'Obesity_Type_II'),
#   Text(6, 0, 'Obesity_Type_III')])

# %%
l=["FCVC","FAF","TUE","CH2O","NCP"]
for i in l:
    sns.scatterplot(x=d[i],y=d["Weight"],hue=d["Gender"])
    plt.show()

# %%
m=["family_history_with_overweight","FAVC","CAEC","SCC"]
for i in m:
    sns.countplot(x=d[i],hue=d["NObeyesdad"],data=d)
    plt.xticks(rotation=30)
    plt.show()

# %%
col=["family_history_with_overweight","FAVC","SMOKE","SCC"]
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
d[col]=d[col].apply(le.fit_transform)
d
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                               1
# 1     Female  21.000000  1.520000   56.000000                               1
# 2       Male  23.000000  1.800000   77.000000                               1
# 3       Male  27.000000  1.800000   87.000000                               0
# 4       Male  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106  Female  20.976842  1.710730  131.408528                               1
# 2107  Female  21.982942  1.748584  133.742943                               1
# 2108  Female  22.524036  1.752206  133.689352                               1
# 2109  Female  24.361936  1.739450  133.346641                               1
# 2110  Female  23.664709  1.738836  133.472641                               1
#
# ...

# %%
d=pd.get_dummies(d,columns=["Gender","CAEC","CALC","MTRANS"],drop_first=True)
d
# Out:
#             Age    Height      Weight  family_history_with_overweight  FAVC  \
# 0     21.000000  1.620000   64.000000                               1     0
# 1     21.000000  1.520000   56.000000                               1     0
# 2     23.000000  1.800000   77.000000                               1     0
# 3     27.000000  1.800000   87.000000                               0     0
# 4     22.000000  1.780000   89.800000                               0     0
# ...         ...       ...         ...                             ...   ...
# 2106  20.976842  1.710730  131.408528                               1     1
# 2107  21.982942  1.748584  133.742943                               1     1
# 2108  22.524036  1.752206  133.689352                               1     1
# 2109  24.361936  1.739450  133.346641                               1     1
# 2110  23.664709  1.738836  133.472641                               1     1
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
d1=d[["Age","Height","Weight","CH2O","FCVC","NCP","FAF","TUE"]]
d1=sc.fit_transform(d1)
d1=pd.DataFrame(d1,columns=["Age","Height","Weight","CH2O","FCVC","NCP","FAF","TUE"])
d1
# Out:
#            Age    Height    Weight      CH2O  FCVC       NCP       FAF  \
# 0     0.148936  0.320755  0.186567  0.500000   0.5  0.666667  0.000000
# 1     0.148936  0.132075  0.126866  1.000000   1.0  0.666667  1.000000
# 2     0.191489  0.660377  0.283582  0.500000   0.5  0.666667  0.666667
# 3     0.276596  0.660377  0.358209  0.500000   1.0  0.666667  0.666667
# 4     0.170213  0.622642  0.379104  0.500000   0.5  0.000000  0.000000
# ...        ...       ...       ...       ...   ...       ...       ...
# 2106  0.148443  0.491943  0.689616  0.364070   1.0  0.666667  0.558756
# 2107  0.169850  0.563366  0.707037  0.502565   1.0  0.666667  0.447130
# 2108  0.181362  0.570200  0.706637  0.527097   1.0  0.666667  0.471403
# 2109  0.220467  0.546132  0.704079  0.926170   1.0  0.666667  0.379702
# 2110  0.205632  0.544974  0.705020  0.931757   1.0  0.666667  0.342151
#
#            TUE
# 0     0.500000
# 1     0.000000
# 2     0.500000
# 3     0.000000
# 4     0.000000
# ...        ...
# ...

# %%
d=d.drop(["Age","Height","Weight","CH2O","FCVC","NCP","FAF","TUE"],axis=1)
d
# Out:
#       family_history_with_overweight  FAVC  SMOKE  SCC           NObeyesdad  \
# 0                                  1     0      0    0        Normal_Weight
# 1                                  1     0      1    1        Normal_Weight
# 2                                  1     0      0    0        Normal_Weight
# 3                                  0     0      0    0   Overweight_Level_I
# 4                                  0     0      0    0  Overweight_Level_II
# ...                              ...   ...    ...  ...                  ...
# 2106                               1     1      0    0     Obesity_Type_III
# 2107                               1     1      0    0     Obesity_Type_III
# 2108                               1     1      0    0     Obesity_Type_III
# 2109                               1     1      0    0     Obesity_Type_III
# 2110                               1     1      0    0     Obesity_Type_III
#
# ...

# %%
d2=pd.concat([d,d1],axis=1)
d2
# Out:
#       family_history_with_overweight  FAVC  SMOKE  SCC           NObeyesdad  \
# 0                                  1     0      0    0        Normal_Weight
# 1                                  1     0      1    1        Normal_Weight
# 2                                  1     0      0    0        Normal_Weight
# 3                                  0     0      0    0   Overweight_Level_I
# 4                                  0     0      0    0  Overweight_Level_II
# ...                              ...   ...    ...  ...                  ...
# 2106                               1     1      0    0     Obesity_Type_III
# 2107                               1     1      0    0     Obesity_Type_III
# 2108                               1     1      0    0     Obesity_Type_III
# 2109                               1     1      0    0     Obesity_Type_III
# 2110                               1     1      0    0     Obesity_Type_III
#
# ...

# %%
y=d2["NObeyesdad"]

# %%
x=d2.drop(["NObeyesdad"],axis=1)
x
# Out:
#       family_history_with_overweight  FAVC  SMOKE  SCC  Gender_Male  \
# 0                                  1     0      0    0        False
# 1                                  1     0      1    1        False
# 2                                  1     0      0    0         True
# 3                                  0     0      0    0         True
# 4                                  0     0      0    0         True
# ...                              ...   ...    ...  ...          ...
# 2106                               1     1      0    0        False
# 2107                               1     1      0    0        False
# 2108                               1     1      0    0        False
# 2109                               1     1      0    0        False
# 2110                               1     1      0    0        False
#
#       CAEC_Frequently  CAEC_Sometimes  CAEC_no  CALC_Frequently  \
# 0               False            True    False            False
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=50)
xtrain
# Out:
#       family_history_with_overweight  FAVC  SMOKE  SCC  Gender_Male  \
# 496                                1     1      0    0         True
# 974                                1     1      0    0        False
# 1484                               1     1      0    0        False
# 561                                0     1      0    0        False
# 1104                               1     1      0    0        False
# ...                              ...   ...    ...  ...          ...
# 132                                1     1      1    1        False
# 2014                               1     1      0    0        False
# 1931                               1     1      0    0        False
# 1504                               1     1      0    0        False
# 1712                               1     1      0    0         True
#
#       CAEC_Frequently  CAEC_Sometimes  CAEC_no  CALC_Frequently  \
# 496             False            True    False            False
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "DecisionTree":DecisionTreeClassifier(),
    "KNearestNeighbors":KNeighborsClassifier()}
for name, model in models.items():
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    score=model.score(xtest,ytest)
    cn=confusion_matrix(ytest,ypred)
    print(model,score)
# Out:
# C:\Users\anusr\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression() 0.7541371158392435
# RandomForestClassifier() 0.9574468085106383
# SVC() 0.8014184397163121
# DecisionTreeClassifier() 0.9432624113475178
# KNeighborsClassifier() 0.7966903073286052

# %%
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier(random_state=42)
param_grid = {
    "n_estimators": [50, 100, 200, 300],    # Number of trees in the forest
    "max_depth": [None, 10, 20, 30],       # Maximum depth of trees
    "min_samples_split": [2, 5, 10],       # Min samples required to split a node
    "min_samples_leaf": [1, 2, 4],         # Min samples required at leaf node
    "bootstrap": [True, False]             # Whether bootstrap sampling is used
}
grid_search = GridSearchCV(
    estimator=rf, 
    param_grid=param_grid, 
    scoring="accuracy",  # Metric to evaluate
    cv=5,                # 5-fold cross-validation
    verbose=2,           # Show progress
    n_jobs=-1            # Use all available CPU cores
)


grid_search.fit(xtrain, ytrain)
best_model = grid_search.best_estimator_
test_score = best_model.score(xtest, ytest)
print("Test Accuracy:", test_score)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# C:\Users\anusr\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Test Accuracy: 0.9550827423167849

# %%
dt = DecisionTreeClassifier(random_state=42)


param_grid = {
    "criterion": ["gini", "entropy"],       
    "max_depth": [None, 5, 10, 20],         
    "min_samples_split": [2, 5, 10],        
    "min_samples_leaf": [1, 2, 4],          
    "max_features": [None, "sqrt", "log2"]  
}
grid_search1 = GridSearchCV(
    estimator=dt, 
    param_grid=param_grid, 
    scoring="accuracy",  # Metric for evaluation
    cv=5,                # 5-fold cross-validation
    verbose=2,           # Show progress
    n_jobs=-1            # Use all available CPU cores
)


grid_search1.fit(xtrain, ytrain)
best_model1 = grid_search1.best_estimator_
test_score1 = best_model1.score(xtest, ytest)
print("Test Accuracy:", test_score1)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Test Accuracy: 0.9527186761229315
